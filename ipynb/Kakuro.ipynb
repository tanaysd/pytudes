# %% [markdown]
# <div style="text-align:right"><i>Peter Norvig<br>2024</i></div>
#
# # Kakuro Puzzles
#
# This notebook demonstrates generating and solving a small Kakuro puzzle using Python.

# %%
from kakuro import generate_example_puzzle, solve_kakuro
runs, solution = generate_example_puzzle()
print('Runs:', runs)
print('Expected solution:', solution)
print('Solved:', solve_kakuro(runs))
